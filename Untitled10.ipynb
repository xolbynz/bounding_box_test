# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt

# %%
import pandas as pd

# %%
def boundingbox(img,df):
    for X in range (0,len(df)):
        label=df[0][X]
        x1=round(float(df[4][X]))
        y1=round(float(df[5][X]))
        x2=round(float(df[6][X]))
        y2=round(float(df[7][X]))
        img=cv2.rectangle(img,(x1,y1),(x2,y2),(0,255,0),1)
        img=cv2.putText(img, label, (x1-10,y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,255,0), 1)
    plt.imshow(img)
    plt.show()
    cv2.imshow('img',img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
img=cv2.imread('Downloads/Kitti_traning_dataset_5/000000.png')
df=pd.read_csv('Downloads/Kitti_traning_dataset_5/000000.txt',sep=' ',header=None)

# %%
boundingbox(img,df)

# %%
img=cv2.imread('Downloads/Kitti_traning_dataset_5/000001.png')
df=pd.read_csv('Downloads/Kitti_traning_dataset_5/000001.txt',sep=' ',header=None)

# %%
boundingbox(img,df)

# %%
img=cv2.imread('Downloads/Kitti_traning_dataset_5/000002.png')
df=pd.read_csv('Downloads/Kitti_traning_dataset_5/000002.txt',sep=' ',header=None)

# %%
boundingbox(img,df)

# %%
img=cv2.imread('Downloads/Kitti_traning_dataset_5/000003.png')
df=pd.read_csv('Downloads/Kitti_traning_dataset_5/000003.txt',sep=' ',header=None)

# %%
boundingbox(img,df)

# %%
img=cv2.imread('Downloads/Kitti_traning_dataset_5/000004.png')
df=pd.read_csv('Downloads/Kitti_traning_dataset_5/000004.txt',sep=' ',header=None)

# %%
boundingbox(img,df)

# %%
img=cv2.imread('Downloads/Kitti_traning_dataset_5/000005.png')
df=pd.read_csv('Downloads/Kitti_traning_dataset_5/000005.txt',sep=' ',header=None)

# %%
boundingbox(img,df)
