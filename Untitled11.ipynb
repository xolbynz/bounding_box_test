# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img=cv2.imread('Downloads/Kitti_traning_dataset_5/000000.png',cv2.IMREAD_GRAYSCALE)
cv2.imshow('img',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image_shape = img.shape
print(image_shape)
# Out:
# (370, 1224)

# %%
image = cv2.imread('Downloads/Kitti_traning_dataset_5/000000.png', cv2. IMREAD_UNCHANGED)
image2 = cv2.imread('Downloads/Kitti_traning_dataset_5/000000.png', cv2. IMREAD_GRAYSCALE)
image3 = cv2.imread('Downloads/Kitti_traning_dataset_5/000000.png', cv2. IMREAD_GRAYSCALE)
image4 = cv2.imread('Downloads/Kitti_traning_dataset_5/000000.png', cv2. IMREAD_GRAYSCALE)
for i in range (0, 220):
    for j in range (0, 220):
        if image3[i,j] > 155:
            image3[i,j] = 255
            continue
        image3[i,j] += 100

for i in range (0, 220):
    for j in range (0, 220):
        if image4[i,j] < 100:
            image4[i,j] = 0
            continue
        image4[i,j] -= 100

# %%
cv2.imshow("test", image)
cv2.imshow("test2", image2)
cv2.imshow("test3", image3)
cv2.imshow("test4", image4)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
src = cv2.imread("Downloads/Kitti_traning_dataset_5/000000.png", cv2.IMREAD_COLOR)

height, width, channel = src.shape
matrix = cv2.getRotationMatrix2D((width/2, height/2), 90, 1)
dst = cv2.warpAffine(src, matrix, (width, height))

cv2.imshow("src", src)
cv2.imshow("dst", dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
def rotation(img,degree):
    height, width, channel = img.shape
    matrix = cv2.getRotationMatrix2D((width/2, height/2), degree, 1)
    dst = cv2.warpAffine(img, matrix, (width, height))
    plt.imshow(dst)
    plt.show()
    cv2.imshow("img", dst)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    return dst

# %%
img = cv2.imread("Downloads/Kitti_traning_dataset_5/000000.png", cv2.IMREAD_COLOR)

# %%
dst=rotation(img,120)

# %%
img.set(cv2.CAP_PROP_FRAME_HEIGHT,360)
img.set(cv2.CAP_PROP_FRAME_WIDTH,640)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-652f7f6158c9> in <module>
# ----> 1 img.set(cv2.CAP_PROP_FRAME_HEIGHT,360)
#       2 img.set(cv2.CAP_PROP_FRAME_WIDTH,640)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'set'

# %%
dst = cv2.resize(img, dsize=(640, 480), interpolation=cv2.INTER_AREA)

# %%
cv2.imshow("img", dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img
